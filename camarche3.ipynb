# %% [markdown]
# <a href="https://colab.research.google.com/github/naphtalimalka/test/blob/main/camarche3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inputFolderDrive = "/content/drive/My Drive/meching/Input"
outputFolderDrive = "/content/drive/My Drive/meching/Output"

# Local notebook paths (Internal Colab disk - faster for processing)
workingDir = "/content/currentProject"
meshroomRoot = workingDir + "/meshroom"
filesInput = workingDir + "/input"
filesOutput = workingDir + "/output"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -v $workingDir
# !mkdir -v $meshroomRoot
# !mkdir -v $filesOutput
# !mkdir -v $filesInput
# !mkdir -v $outputFolderDrive
# Out:
# mkdir: cannot create directory ‘/content/currentProject’: File exists
# mkdir: cannot create directory ‘/content/currentProject/meshroom’: File exists
# mkdir: cannot create directory ‘/content/currentProject/output’: File exists
# mkdir: cannot create directory ‘/content/currentProject/input’: File exists
# mkdir: cannot create directory ‘/content/drive/My’: Operation not supported
# mkdir: cannot create directory ‘Drive/meching/Output’: No such file or directory

# %%
# %cd $workingDir
# Out:
# /content/currentProject

# %%
inputFolderDrive = "/content/drive/My Drive/meching/Input"
# !cp -arv "{inputFolderDrive}"/* "{filesInput}"
# Out:
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103556.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103556.jpg'
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103611.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103611.jpg'
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103622.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103622.jpg'
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103633.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103633.jpg'
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103643.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103643.jpg'
# '/content/drive/My Drive/meching/Input/Copie de Screenshot 2026-04-09 103654.jpg' -> '/content/currentProject/input/Copie de Screenshot 2026-04-09 103654.jpg'
# ...

# %%
# 1. On nettoie
# !rm -rf /content/meshroom
# !mkdir -p /content/meshroom

# 2. ON TÉLÉCHARGE LE LOGICIEL (La ligne qui manquait)
print("📥 Téléchargement de Meshroom...")
# !wget -N https://github.com/alicevision/meshroom/releases/download/v2019.1.0/Meshroom-2019.1.0-linux.tar.gz

# 3. On extrait
print("📦 Extraction de Meshroom en cours...")
# !tar xzf Meshroom-2019.1.0-linux.tar.gz -C /content/meshroom --strip-components=1

# 4. Vérification immédiate
import os
if os.path.exists('/content/meshroom/meshroom_photogrammetry'):
    print("✅ SUCCÈS : Meshroom est bien installé au bon endroit !")
else:
    print("❌ ÉCHEC : Le fichier est toujours introuvable.")
# Out:
# 📥 Téléchargement de Meshroom...
# --2026-04-10 12:44:00--  https://github.com/alicevision/meshroom/releases/download/v2019.1.0/Meshroom-2019.1.0-linux.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
import glob

# 1. On trouve le chemin
try:
    meshroomRun = glob.glob('/content/meshroom/**/meshroom_photogrammetry', recursive=True)[0]
    print(f"✅ Logiciel trouvé ici : {meshroomRun}")
except IndexError:
    print("❌ ERREUR : Le logiciel n'est pas installé.")

# 2. Configuration des dossiers
input_dir = "/content/drive/My Drive/meching/Input"
output_dir = "/content/drive/My Drive/meching/Output"
cache_dir = "/content/cache"

# !mkdir -p "{output_dir}"
# !mkdir -p "{cache_dir}"

# 3. Lancement SANS l'argument qui a bloqué
print(f"🚀 Lancement de la reconstruction...")

# !{meshroomRun} --input "{input_dir}" --output "{output_dir}" --cache "{cache_dir}"
# Out:
# ✅ Logiciel trouvé ici : /content/meshroom/meshroom_photogrammetry
# 🚀 Lancement de la reconstruction...
# Plugins loaded:  CameraCalibration, CameraInit, CameraLocalization, CameraRigCalibration, CameraRigLocalization, ConvertSfMFormat, DepthMap, DepthMapFilter, ExportAnimatedCamera, ExportMaya, FeatureExtraction, FeatureMatching, ImageMatching, ImageMatchingMultiSfM, KeyframeSelection, MeshDecimate, MeshDenoising, MeshFiltering, MeshResampling, Meshing, PrepareDenseScene, Publish, SfMAlignment, SfMTransform, StructureFromMotion, Texturing
# Program called with the following parameters:
#  * allowSingleView = 1
#  * defaultCameraModel = "" (default)
#  * defaultFieldOfView = 45
#  * defaultFocalLengthPix = -1 (default)
#  * defaultIntrinsic = "" (default)
#  * groupCameraFallback =  Unknown Type "20EGroupCameraFallback"
#  * imageFolder = "" (default)
#  * input = "/tmp/tmpqmg7yyn8/CameraInit/c448939571d5c70b05c9ae4ad416ada37d6273ca//viewpoints.sfm"
# ...

# %%
import os
import glob

# --- 1. LOCALISATION DU LOGICIEL ---
try:
    meshroom_path = glob.glob('/content/meshroom/**/meshroom_photogrammetry', recursive=True)[0]
    print(f"✅ Logiciel trouvé ici : {meshroom_path}")
except IndexError:
    print("❌ ERREUR : Meshroom n'est pas installé. Relance l'installation.")

# --- 2. CONFIGURATION DES CHEMINS ---
input_dir = "/content/drive/My Drive/meching/Input"
output_dir = "/content/drive/My Drive/meching/Output" # Sauvegarde directe sur ton Drive
cache_dir = "/content/cache"

# !mkdir -p "{input_dir}"
# !mkdir -p "{output_dir}"
# !mkdir -p "{cache_dir}"

# --- 3. VÉRIFICATION DES PHOTOS ---
photos = []
for ext in ['*.jpg', '*.JPG', '*.jpeg', '*.JPEG', '*.png', '*.PNG']:
    photos.extend(glob.glob(f'{input_dir}/{ext}'))

if len(photos) > 0:
    print(f"✅ {len(photos)} photos détectées dans {input_dir}")

    # Autorisation
    # !chmod +x "{meshroom_path}"

    # --- 4. LANCEMENT DU CALCUL ---
    print("🚀 Lancement de la reconstruction 3D...")
    # !{meshroom_path} --input "{input_dir}" --output "{output_dir}" --cache "{cache_dir}"

    print(f"🏁 TERMINÉ ! Ton modèle est dans ton Drive : meching/Output")
else:
    print(f"❌ ERREUR : Aucune photo trouvée dans {input_dir}")
# Out:
# ✅ Logiciel trouvé ici : /content/meshroom/meshroom_photogrammetry
# ✅ 5 photos détectées dans /content/drive/My Drive/meching/Input
# 🚀 Lancement de la reconstruction 3D...
# Plugins loaded:  CameraCalibration, CameraInit, CameraLocalization, CameraRigCalibration, CameraRigLocalization, ConvertSfMFormat, DepthMap, DepthMapFilter, ExportAnimatedCamera, ExportMaya, FeatureExtraction, FeatureMatching, ImageMatching, ImageMatchingMultiSfM, KeyframeSelection, MeshDecimate, MeshDenoising, MeshFiltering, MeshResampling, Meshing, PrepareDenseScene, Publish, SfMAlignment, SfMTransform, StructureFromMotion, Texturing
# Program called with the following parameters:
#  * allowSingleView = 1
#  * defaultCameraModel = "" (default)
#  * defaultFieldOfView = 45
#  * defaultFocalLengthPix = -1 (default)
#  * defaultIntrinsic = "" (default)
#  * groupCameraFallback =  Unknown Type "20EGroupCameraFallback"
#  * imageFolder = "" (default)
# ...

# %%
import os
from google.colab import files

# On crée un fichier ZIP pour tout avoir ensemble
# !zip -r meshroom_resultat_buddha.zip /content/output_buddha/

# On télécharge le ZIP
files.download('meshroom_resultat_buddha.zip')
# Out:
#   adding: content/output_buddha/ (stored 0%)
#   adding: content/output_buddha/texturedMesh.mtl (deflated 28%)
#   adding: content/output_buddha/texture_0.png (deflated 3%)
#   adding: content/output_buddha/texturedMesh.obj (deflated 69%)

# %%
# 1. Connecter le Drive (si ce n'est pas déjà fait)
from google.colab import drive
drive.mount('/content/drive')

# 2. Créer un dossier dédié dans ton Drive
# !mkdir -p "/content/drive/MyDrive/Meshroom_Export"

# 3. Copier les fichiers du modèle 3D vers ce dossier
# !cp /content/output_buddha/texturedMesh.obj "/content/drive/MyDrive/Meshroom_Export/"
# !cp /content/output_buddha/texturedMesh.mtl "/content/drive/MyDrive/Meshroom_Export/"
# !cp /content/output_buddha/texture_0.png "/content/drive/MyDrive/Meshroom_Export/"

print("✅ Tes fichiers ont été copiés dans le dossier 'Meshroom_Export' de ton Drive !")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot stat '/content/output_buddha/texturedMesh.obj': No such file or directory
# cp: cannot stat '/content/output_buddha/texturedMesh.mtl': No such file or directory
# cp: cannot stat '/content/output_buddha/texture_0.png': No such file or directory
# ✅ Tes fichiers ont été copiés dans le dossier 'Meshroom_Export' de ton Drive !
